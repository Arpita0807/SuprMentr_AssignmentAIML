# %%
1. Google Search :
Machine Learning analyzes your search history and keywords to rank the most relevant results for your query.

2. YouTube Recommendations :
ML models study your watch time, likes, and searches to recommend videos similar to your interests.

3. Google Maps:
AI uses real-time traffic data and past travel patterns to predict the fastest route and travel time.

4. Smartphone Face Unlock:
ML is trained on facial features to recognize and authenticate the user securely.

5. Email Spam Filter:
Machine Learning classifies emails by learning from past spam and non-spam messages.

6. Voice Assistants (Google Assistant / Siri):
AI converts speech to text using ML models and understands commands using Natural Language Processing.

7. Netflix Recommendations:
ML analyzes your viewing history and ratings to suggest movies and series you may like.

8. Autocorrect & Predictive Text:
AI learns from typing patterns to predict and correct words while typing.

9. Online Shopping (Amazon / Flipkart):

ML tracks browsing and purchase history to recommend products and show personalized ads.

10. Social Media Feeds (Instagram / Facebook)

AI ranks posts based on your interactions such as likes, comments, and time spent on posts.
