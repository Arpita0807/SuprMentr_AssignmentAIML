# %%
1. PROBLEM STATEMENT
Businesses often face difficulty in understanding customer behavior due to the lack of proper segmentation techniques. Without grouping customers based on their purchasing patterns, companies fail to design effective marketing strategies, leading to reduced customer satisfaction and lower profits. The goal of this project is to analyze customer data and segment them into meaningful groups using machine learning, enabling businesses to target customers efficiently and improve decision-making. 

2. DATASET
a.Mall Customer Segmentation Dataset
b. Customer ID
c. Age
d. Gender
e. Annual Income (k$)
f. Spending Score (1–100)

3. ALGORITHM / METHODOLOGY
Step 1 - Data Collection :
Load the dataset containing customer demographic and spending details
Step 2 - Preprocessing :
Select relevant features such as Annual Income and Spending Score for clustering
Step 3 - Model (K-Means) :
Apply K-Means clustering algorithm to group customers into different segments
Step 4 - Optimization :
Use the Elbow Method to determine the optimal number of clusters
Step 5 - Visualization :
Plot clusters and centroids using scatter plots for better understanding

4. EXPECTED OUTPUT
Clear segmentation of customers into distinct groups
Identification of categories such as:
  High income, high spending customers
  High income, low spending customers
  Low income, high spending customers
  Low income, low spending customers
Graphical representation of clusters using scatter plots
Business insights for targeted marketing and customer retention
